# %% [markdown]
# ```
# # This is formatted as code
# ```

# %% [markdown]
# #BASIC OF DATA ANALATICS
#
# 1. Define the role of a Data Analyst in your own words. What value do they bring to an organization?
# <= A data analyst is responsible for collecting,organizing, and studying data to helps a company make better business decisions.
# It help organizations understatnd trends, improve efficiency , identify oppertunities, and solves problem.
#
# 2. List three tools commonly used by Data Analysts and explain what each is mainly used for.
# <= there are three tools like
# 1.Excel- it is used for data entry,cleaning and basic analysis Excel helps analysts create charts,pivot tables.
# 2.SQL-it is used for extract,manipulte and mange data stored in databases. it helps analysts retrieve the data.
# 3.tableau-it is used for data visualization and dashboard creation.
#
# 3. Write the end-to-end analytics workflow in the correct order and briefly explain each step.
# <= a.Define the problem - understand the business problem or question that needs to be answered using data.
# b. Data collection-data collect the various source like spreadsheets,APIs or surveys.
# c. Data cleaning - remove duplicates,correct errors,handle missing value.
# d.Data transfering-explore the data using statistical methods and visualizations to find patterns and insights.
# e. Data visulization- create charts,dashboards and reports to present the finding clearly.
# f. Data analysis - share insights with stakeholders to support business decisions and actions.
#
# 4. What is Prompt Engineering, and explain any two types of prompts used in Generative AI?
# <= It is the process of designing and optimizing input prompts to effectively communicate with genrative AI models like -chatGPT.
# 1.instruction based prompt- this type of prompt gives direct instructions to the AI about what to do.
# 2.Example based prompt- this prompt provides examples to show the AI the desired pattern or style of response.
#
# 5. What are the key differences between a Business Analyst and a Data Analyst in terms of roles, responsibilities, and focus?
# <= Business analyst-
# Role- acts as a bridge between business stakeholders and technical teams.
# Responsibilities- Gather business requirements- define project goals- suggest process improvements- communicates with management and IT teams.
# Focus- focus on understanding business needs and improving business processes.
#
# Data Analyst-
# Role- works with data to find trends,patterns and insights
# Responsibilities - collect and clean data use statistical tools to analyze data-create dashboards and reports support data-drivien decisions.
# Focus- focus on collecting the data,analyzing and interpreting,support decision making.
#
# 6. Explain any three AI-powered ETL (Extract, Transform, Load) tools and how they are used in analytics.
# <=1.Talend data fabric- talend is powerful ETL platform that used AI and machine learning to automate data integration and cleansing tasks
# 2.IDMC(informatica intelligent data management cloud)- informatica AI engine,called CLAIRE,enhances ETL processes through automation and intelligent data handling.
# 3.Microsoft Azure data factory(ADF) - Azure data factory integrates Al for optimizing and automating ETL pipelines in the cloud.
#
# 7. Give three applications of Data Analytics across different industries and explain how it creates value.
# <= 1.Healthcare- predictive analytics for patient care
# 2.Retails-Customer behavior and recommendation system
# 3.Finance- Fraud detection and risk management
#
# 8. Explain the evolution of analytics, highlighting the different stages from Descriptive to Generative AI.
# <= IT shows how organizations have moved from simply understanding what happened in the past to predicting and even generative intelligent insights and decisions using AI.
#
# Descriptive- to summarize past data and understand what has already occurred.
# dashboards,reports,data visulization(Excel,power BI ,Tableau)
